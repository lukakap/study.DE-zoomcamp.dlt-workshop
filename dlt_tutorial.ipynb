# %% [markdown]
# FROM DLT SITE WILL TRY OUT SOME THINGS - https://dlthub.com/docs/getting-started

# %%
# !pip install -U dlt
# Out:
# Collecting dlt
#   Obtaining dependency information for dlt from https://files.pythonhosted.org/packages/6f/78/939b5eb62075a5e293261265d5022ee387cbfa86802750446eb8d9f716a2/dlt-0.4.3-py3-none-any.whl.metadata
#   Downloading dlt-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (6.0)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (1.4.39)
# Collecting astunparse>=1.6.3 (from dlt)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click>=7.1 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (8.0.4)
# Requirement already satisfied: fsspec>=2022.4.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (2023.4.0)
# Collecting gitpython>=3.1.29 (from dlt)
#   Obtaining dependency information for gitpython>=3.1.29 from https://files.pythonhosted.org/packages/45/c6/a637a7a11d4619957cb95ca195168759a4502991b1b91c13d3203ffc3748/GitPython-3.1.41-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.41-py3-none-any.whl.metadata (14 kB)
# Collecting giturlparse>=0.10.0 (from dlt)
#   Obtaining dependency information for giturlparse>=0.10.0 from https://files.pythonhosted.org/packages/dd/94/c6ff3388b8e3225a014e55aed957188639aa0966443e0408d38f0c9614a7/giturlparse-0.12.0-py2.py3-none-any.whl.metadata
#   Downloading giturlparse-0.12.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting hexbytes>=0.2.2 (from dlt)
#   Obtaining dependency information for hexbytes>=0.2.2 from https://files.pythonhosted.org/packages/73/99/f6beab7c3fe2ad62f6763a5e92af476225d74408b2588fe5614a67c63ee4/hexbytes-1.0.0-py3-none-any.whl.metadata
#   Downloading hexbytes-1.0.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting humanize>=4.4.0 (from dlt)
#   Obtaining dependency information for humanize>=4.4.0 from https://files.pythonhosted.org/packages/aa/2b/2ae0c789fd08d5b44e745726d08a17e6d3d7d09071d05473105edc7615f2/humanize-4.9.0-py3-none-any.whl.metadata
#   Downloading humanize-4.9.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting jsonpath-ng>=1.5.3 (from dlt)
#   Obtaining dependency information for jsonpath-ng>=1.5.3 from https://files.pythonhosted.org/packages/16/0a/3b1ee3721b4bd684b0e29c724ab82ed3b2c0e42285beb8bf9e18de8c903f/jsonpath_ng-1.6.1-py3-none-any.whl.metadata
#   Downloading jsonpath_ng-1.6.1-py3-none-any.whl.metadata (18 kB)
# Collecting makefun>=1.15.0 (from dlt)
#   Obtaining dependency information for makefun>=1.15.0 from https://files.pythonhosted.org/packages/47/45/51d50062d95a0c2fd8f5f1cc8849878ea5c76d2f6a049a0b9d449272e97f/makefun-1.15.2-py2.py3-none-any.whl.metadata
#   Downloading makefun-1.15.2-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting orjson>=3.6.7 (from dlt)
#   Obtaining dependency information for orjson>=3.6.7 from https://files.pythonhosted.org/packages/9a/e5/8157405685724de602a3d08c3f515f91dc5a7383c5df989622309ac3eed0/orjson-3.9.13-cp311-none-win_amd64.whl.metadata
#   Downloading orjson-3.9.13-cp311-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.6 kB ? eta -:--:--
#      ------------------------ --------------- 30.7/50.6 kB 1.4 MB/s eta 0:00:01
#      ------------------------ --------------- 30.7/50.6 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 50.6/50.6 kB 517.4 kB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.1 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (23.1)
# Collecting pathvalidate>=2.5.2 (from dlt)
#   Obtaining dependency information for pathvalidate>=2.5.2 from https://files.pythonhosted.org/packages/0c/ab/673cce13ab635fd755d206b18c0a371ef6e28ddbe25fadba9ae6c59f22a5/pathvalidate-3.2.0-py3-none-any.whl.metadata
#   Downloading pathvalidate-3.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting pendulum>=2.1.2 (from dlt)
#   Obtaining dependency information for pendulum>=2.1.2 from https://files.pythonhosted.org/packages/60/19/c13307ea8504d2c02c63c9dffdae1cefbd068b636ec7b18ccf2ec064d246/pendulum-3.0.0-cp311-none-win_amd64.whl.metadata
#   Downloading pendulum-3.0.0-cp311-none-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: pytz>=2022.6 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (2023.3.post1)
# Requirement already satisfied: requests>=2.26.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (2.31.0)
# Collecting requirements-parser>=0.5.0 (from dlt)
#   Downloading requirements_parser-0.5.0-py3-none-any.whl (18 kB)
# Collecting semver>=2.13.0 (from dlt)
#   Obtaining dependency information for semver>=2.13.0 from https://files.pythonhosted.org/packages/9a/77/0cc7a8a3bc7e53d07e8f47f147b92b0960e902b8254859f4aee5c4d7866b/semver-3.0.2-py3-none-any.whl.metadata
#   Downloading semver-3.0.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: setuptools>=65.6.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (68.0.0)
# Collecting simplejson>=3.17.5 (from dlt)
#   Obtaining dependency information for simplejson>=3.17.5 from https://files.pythonhosted.org/packages/b6/8e/3e12d122dfdf549a8d12eaf39954ee39f2027060aa38b63430f8ab3244e7/simplejson-3.19.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading simplejson-3.19.2-cp311-cp311-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: tenacity>=8.0.2 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (8.2.2)
# Collecting tomlkit>=0.11.3 (from dlt)
#   Obtaining dependency information for tomlkit>=0.11.3 from https://files.pythonhosted.org/packages/6e/43/159750d32481f16e34cc60090b53bc0a14314ad0c1f67a9bb64f3f3a0551/tomlkit-0.12.3-py3-none-any.whl.metadata
#   Downloading tomlkit-0.12.3-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (4.7.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\luka\anaconda3\lib\site-packages (from dlt) (2023.3)
# Collecting win-precise-time>=1.4.2 (from dlt)
#   Obtaining dependency information for win-precise-time>=1.4.2 from https://files.pythonhosted.org/packages/f9/9c/46d69220d468c82ca2044284c5a8089705c5eb66be416abcbba156365a14/win_precise_time-1.4.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading win_precise_time-1.4.2-cp311-cp311-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\luka\anaconda3\lib\site-packages (from astunparse>=1.6.3->dlt) (0.38.4)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\users\luka\anaconda3\lib\site-packages (from astunparse>=1.6.3->dlt) (1.16.0)
# Requirement already satisfied: colorama in c:\users\luka\anaconda3\lib\site-packages (from click>=7.1->dlt) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.29->dlt)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: ply in c:\users\luka\anaconda3\lib\site-packages (from jsonpath-ng>=1.5.3->dlt) (3.11)
# Requirement already satisfied: python-dateutil>=2.6 in c:\users\luka\anaconda3\lib\site-packages (from pendulum>=2.1.2->dlt) (2.8.2)
# Collecting time-machine>=2.6.0 (from pendulum>=2.1.2->dlt)
#   Obtaining dependency information for time-machine>=2.6.0 from https://files.pythonhosted.org/packages/59/4d/7bdf88f9e7227bb52d6cb18382ea28ba3b9de242125f75385e2c13c88318/time_machine-2.13.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading time_machine-2.13.0-cp311-cp311-win_amd64.whl.metadata (21 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\luka\anaconda3\lib\site-packages (from requests>=2.26.0->dlt) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luka\anaconda3\lib\site-packages (from requests>=2.26.0->dlt) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luka\anaconda3\lib\site-packages (from requests>=2.26.0->dlt) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luka\anaconda3\lib\site-packages (from requests>=2.26.0->dlt) (2023.11.17)
# Collecting types-setuptools>=57.0.0 (from requirements-parser>=0.5.0->dlt)
#   Obtaining dependency information for types-setuptools>=57.0.0 from https://files.pythonhosted.org/packages/b8/b9/fd100e50ab166e5c2a6933f04c711e378b6ec93e2c74f84a693aa408d8e1/types_setuptools-69.0.0.20240125-py3-none-any.whl.metadata
#   Downloading types_setuptools-69.0.0.20240125-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\luka\anaconda3\lib\site-packages (from SQLAlchemy>=1.4.0->dlt) (2.0.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading dlt-0.4.3-py3-none-any.whl (540 kB)
#    ---------------------------------------- 0.0/540.2 kB ? eta -:--:--
#    ----- ---------------------------------- 71.7/540.2 kB 3.8 MB/s eta 0:00:01
#    ----- ---------------------------------- 71.7/540.2 kB 3.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 153.6/540.2 kB 1.1 MB/s eta 0:00:01
#    --------------- ------------------------ 204.8/540.2 kB 1.4 MB/s eta 0:00:01
#    --------------------- ------------------ 286.7/540.2 kB 1.3 MB/s eta 0:00:01
#    --------------------------- ------------ 368.6/540.2 kB 1.4 MB/s eta 0:00:01
#    ------------------------------- -------- 419.8/540.2 kB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 501.8/540.2 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 540.2/540.2 kB 1.4 MB/s eta 0:00:00
# Downloading GitPython-3.1.41-py3-none-any.whl (196 kB)
#    ---------------------------------------- 0.0/196.4 kB ? eta -:--:--
#    ------------------------- -------------- 122.9/196.4 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 196.4/196.4 kB 3.0 MB/s eta 0:00:00
# Downloading giturlparse-0.12.0-py2.py3-none-any.whl (15 kB)
# Downloading hexbytes-1.0.0-py3-none-any.whl (5.9 kB)
# Downloading humanize-4.9.0-py3-none-any.whl (126 kB)
#    ---------------------------------------- 0.0/126.8 kB ? eta -:--:--
#    ------------ --------------------------- 41.0/126.8 kB ? eta -:--:--
#    ---------------------------------------- 126.8/126.8 kB 2.5 MB/s eta 0:00:00
# Downloading jsonpath_ng-1.6.1-py3-none-any.whl (29 kB)
# Downloading makefun-1.15.2-py2.py3-none-any.whl (22 kB)
# Downloading orjson-3.9.13-cp311-none-win_amd64.whl (134 kB)
#    ---------------------------------------- 0.0/134.2 kB ? eta -:--:--
#    --------------------------------- ------ 112.6/134.2 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 134.2/134.2 kB 2.6 MB/s eta 0:00:00
# Downloading pathvalidate-3.2.0-py3-none-any.whl (23 kB)
# Downloading pendulum-3.0.0-cp311-none-win_amd64.whl (293 kB)
#    ---------------------------------------- 0.0/293.5 kB ? eta -:--:--
#    ---------------------- ----------------- 163.8/293.5 kB 3.3 MB/s eta 0:00:01
#    -------------------------- ------------- 194.6/293.5 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 293.5/293.5 kB 2.0 MB/s eta 0:00:00
# Downloading semver-3.0.2-py3-none-any.whl (17 kB)
# Downloading simplejson-3.19.2-cp311-cp311-win_amd64.whl (75 kB)
#    ---------------------------------------- 0.0/75.3 kB ? eta -:--:--
#    ---------------------------------------- 75.3/75.3 kB 4.3 MB/s eta 0:00:00
# Downloading tomlkit-0.12.3-py3-none-any.whl (37 kB)
# Downloading win_precise_time-1.4.2-cp311-cp311-win_amd64.whl (14 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Downloading time_machine-2.13.0-cp311-cp311-win_amd64.whl (19 kB)
# Downloading types_setuptools-69.0.0.20240125-py3-none-any.whl (51 kB)
#    ---------------------------------------- 0.0/51.3 kB ? eta -:--:--
#    ---------------------------------------- 51.3/51.3 kB 1.3 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: makefun, win-precise-time, types-setuptools, tomlkit, smmap, simplejson, semver, pathvalidate, orjson, jsonpath-ng, humanize, hexbytes, giturlparse, astunparse, time-machine, requirements-parser, gitdb, pendulum, gitpython, dlt
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.11.1
#     Uninstalling tomlkit-0.11.1:
#       Successfully uninstalled tomlkit-0.11.1
# Successfully installed astunparse-1.6.3 dlt-0.4.3 gitdb-4.0.11 gitpython-3.1.41 giturlparse-0.12.0 hexbytes-1.0.0 humanize-4.9.0 jsonpath-ng-1.6.1 makefun-1.15.2 orjson-3.9.13 pathvalidate-3.2.0 pendulum-3.0.0 requirements-parser-0.5.0 semver-3.0.2 simplejson-3.19.2 smmap-5.0.1 time-machine-2.13.0 tomlkit-0.12.3 types-setuptools-69.0.0.20240125 win-precise-time-1.4.2

# %%
# !pip install "dlt[duckdb]"
# Out:
# Requirement already satisfied: dlt[duckdb] in c:\users\luka\anaconda3\lib\site-packages (0.4.3)
# Requirement already satisfied: PyYAML>=5.4.1 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (6.0)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (1.4.39)
# Requirement already satisfied: astunparse>=1.6.3 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (1.6.3)
# Requirement already satisfied: click>=7.1 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (8.0.4)
# Collecting duckdb<0.10.0,>=0.6.1 (from dlt[duckdb])
#   Obtaining dependency information for duckdb<0.10.0,>=0.6.1 from https://files.pythonhosted.org/packages/a6/7a/e15904563fa63d7d3cc542a697377486ddea8ba4914810391812ffefc9b1/duckdb-0.9.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading duckdb-0.9.2-cp311-cp311-win_amd64.whl.metadata (798 bytes)
# Requirement already satisfied: fsspec>=2022.4.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (2023.4.0)
# Requirement already satisfied: gitpython>=3.1.29 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (3.1.41)
# Requirement already satisfied: giturlparse>=0.10.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (0.12.0)
# Requirement already satisfied: hexbytes>=0.2.2 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (1.0.0)
# Requirement already satisfied: humanize>=4.4.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (4.9.0)
# Requirement already satisfied: jsonpath-ng>=1.5.3 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (1.6.1)
# Requirement already satisfied: makefun>=1.15.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (1.15.2)
# Requirement already satisfied: orjson>=3.6.7 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (3.9.13)
# Requirement already satisfied: packaging>=21.1 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (23.1)
# Requirement already satisfied: pathvalidate>=2.5.2 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (3.2.0)
# Requirement already satisfied: pendulum>=2.1.2 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (3.0.0)
# Requirement already satisfied: pytz>=2022.6 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (2023.3.post1)
# Requirement already satisfied: requests>=2.26.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (2.31.0)
# Requirement already satisfied: requirements-parser>=0.5.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (0.5.0)
# Requirement already satisfied: semver>=2.13.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (3.0.2)
# Requirement already satisfied: setuptools>=65.6.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (68.0.0)
# Requirement already satisfied: simplejson>=3.17.5 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (3.19.2)
# Requirement already satisfied: tenacity>=8.0.2 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (8.2.2)
# Requirement already satisfied: tomlkit>=0.11.3 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (0.12.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (4.7.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (2023.3)
# Requirement already satisfied: win-precise-time>=1.4.2 in c:\users\luka\anaconda3\lib\site-packages (from dlt[duckdb]) (1.4.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\luka\anaconda3\lib\site-packages (from astunparse>=1.6.3->dlt[duckdb]) (0.38.4)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\users\luka\anaconda3\lib\site-packages (from astunparse>=1.6.3->dlt[duckdb]) (1.16.0)
# Requirement already satisfied: colorama in c:\users\luka\anaconda3\lib\site-packages (from click>=7.1->dlt[duckdb]) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\luka\anaconda3\lib\site-packages (from gitpython>=3.1.29->dlt[duckdb]) (4.0.11)
# Requirement already satisfied: ply in c:\users\luka\anaconda3\lib\site-packages (from jsonpath-ng>=1.5.3->dlt[duckdb]) (3.11)
# Requirement already satisfied: python-dateutil>=2.6 in c:\users\luka\anaconda3\lib\site-packages (from pendulum>=2.1.2->dlt[duckdb]) (2.8.2)
# Requirement already satisfied: time-machine>=2.6.0 in c:\users\luka\anaconda3\lib\site-packages (from pendulum>=2.1.2->dlt[duckdb]) (2.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\luka\anaconda3\lib\site-packages (from requests>=2.26.0->dlt[duckdb]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luka\anaconda3\lib\site-packages (from requests>=2.26.0->dlt[duckdb]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luka\anaconda3\lib\site-packages (from requests>=2.26.0->dlt[duckdb]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luka\anaconda3\lib\site-packages (from requests>=2.26.0->dlt[duckdb]) (2023.11.17)
# Requirement already satisfied: types-setuptools>=57.0.0 in c:\users\luka\anaconda3\lib\site-packages (from requirements-parser>=0.5.0->dlt[duckdb]) (69.0.0.20240125)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\luka\anaconda3\lib\site-packages (from SQLAlchemy>=1.4.0->dlt[duckdb]) (2.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\luka\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.29->dlt[duckdb]) (5.0.1)
# Downloading duckdb-0.9.2-cp311-cp311-win_amd64.whl (10.3 MB)
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.3 MB 330.3 kB/s eta 0:00:32
#    ---------------------------------------- 0.1/10.3 MB 409.6 kB/s eta 0:00:26
#    ---------------------------------------- 0.1/10.3 MB 595.3 kB/s eta 0:00:18
#     --------------------------------------- 0.2/10.3 MB 748.1 kB/s eta 0:00:14
#     --------------------------------------- 0.2/10.3 MB 846.9 kB/s eta 0:00:12
#    - -------------------------------------- 0.4/10.3 MB 1.2 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/10.3 MB 1.2 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/10.3 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/10.3 MB 2.1 MB/s eta 0:00:05
#    ------ --------------------------------- 1.6/10.3 MB 3.3 MB/s eta 0:00:03
#    ------- -------------------------------- 1.9/10.3 MB 3.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.7/10.3 MB 4.5 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/10.3 MB 5.3 MB/s eta 0:00:02
#    --------------- ------------------------ 4.1/10.3 MB 6.0 MB/s eta 0:00:02
#    ------------------ --------------------- 4.7/10.3 MB 6.4 MB/s eta 0:00:01
#    --------------------- ------------------ 5.7/10.3 MB 7.2 MB/s eta 0:00:01
#    ------------------------- -------------- 6.6/10.3 MB 7.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.5/10.3 MB 8.5 MB/s eta 0:00:01
#    ------------------------------- -------- 8.1/10.3 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.8/10.3 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------- -- 9.6/10.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  10.3/10.3 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.3/10.3 MB 10.9 MB/s eta 0:00:00
# Installing collected packages: duckdb
# Successfully installed duckdb-0.9.2

# %%
import dlt
from dlt.sources.helpers import requests

# Create a dlt pipeline that will load
# chess player data to the DuckDB destination
pipeline = dlt.pipeline(
    pipeline_name="chess_pipeline", destination="duckdb", dataset_name="player_data"
)
# Grab some player data from Chess.com API
data = []
for player in ["magnuscarlsen", "rpragchess"]:
    response = requests.get(f"https://api.chess.com/pub/player/{player}")
    response.raise_for_status()
    data.append(response.json())
# Extract, normalize, and load the data
load_info = pipeline.run(data, table_name="player")

# %%
data
# Out:
# [{'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/3889224.121e2094.200x200o.361c2f8a59c2.jpg',
#   'player_id': 3889224,
#   '@id': 'https://api.chess.com/pub/player/magnuscarlsen',
#   'url': 'https://www.chess.com/member/MagnusCarlsen',
#   'name': 'Magnus Carlsen',
#   'username': 'magnuscarlsen',
#   'title': 'GM',
#   'followers': 183584,
#   'country': 'https://api.chess.com/pub/country/NO',
#   'location': 'Norway',
#   'last_online': 1707676983,
#   'joined': 1282856720,
#   'status': 'premium',
#   'is_streamer': False,
#   'verified': False,
#   'league': 'Champion'},
#  {'avatar': 'https://images.chesscomfiles.com/uploads/v1/user/28692936.b7d437d6.200x200o.293777c7e9fd.jpeg',
#   'player_id': 28692936,
#   '@id': 'https://api.chess.com/pub/player/rpragchess',
#   'url': 'https://www.chess.com/member/rpragchess',
#   'name': 'Praggnanandhaa Rameshbabu',
#   'username': 'rpragchess',
#   'title': 'GM',
#   'followers': 6649,
#   'country': 'https://api.chess.com/pub/country/IN',
#   'location': 'CHENNAI',
#   'last_online': 1707658628,
#   'joined': 1466301035,
#   'status': 'premium',
#   'is_streamer': False,
#   'verified': False,
#   'league': 'Crystal'}]

# %%
import duckdb

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# this lets us query data without adding schema prefix to table names
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")

# list all tables
display(conn.sql("DESCRIBE"))

stats_table = conn.sql("SELECT * FROM player").df()

display(stats_table)
# Out:
# ┌────────────────┬─────────────┬─────────────────────┬──────────────────────┬──────────────────────────────┬───────────┐
# │    database    │   schema    │        name         │     column_names     │         column_types         │ temporary │
# │    varchar     │   varchar   │       varchar       │      varchar[]       │          varchar[]           │  boolean  │
# ├────────────────┼─────────────┼─────────────────────┼──────────────────────┼──────────────────────────────┼───────────┤
# │ chess_pipeline │ player_data │ _dlt_loads          │ [load_id, schema_n…  │ [VARCHAR, VARCHAR, BIGINT,…  │ false     │
# │ chess_pipeline │ player_data │ _dlt_pipeline_state │ [version, engine_v…  │ [BIGINT, BIGINT, VARCHAR, …  │ false     │
# │ chess_pipeline │ player_data │ _dlt_version        │ [version, engine_v…  │ [BIGINT, BIGINT, TIMESTAMP…  │ false     │
# │ chess_pipeline │ player_data │ player              │ [avatar, player_id…  │ [VARCHAR, BIGINT, VARCHAR,…  │ false     │
# └────────────────┴─────────────┴─────────────────────┴──────────────────────┴──────────────────────────────┴───────────┘
#                                               avatar  player_id  \
# 0  https://images.chesscomfiles.com/uploads/v1/us...    3889224
# 1  https://images.chesscomfiles.com/uploads/v1/us...   28692936
#
#                                               aid  \
# 0  https://api.chess.com/pub/player/magnuscarlsen
# 1     https://api.chess.com/pub/player/rpragchess
#
#                                           url                       name  \
# 0  https://www.chess.com/member/MagnusCarlsen             Magnus Carlsen
# 1     https://www.chess.com/member/rpragchess  Praggnanandhaa Rameshbabu
#
#         username title  followers                               country  \
# 0  magnuscarlsen    GM     183584  https://api.chess.com/pub/country/NO
# 1     rpragchess    GM       6649  https://api.chess.com/pub/country/IN
#
#   location  last_online      joined   status  is_streamer  verified    league  \
# 0   Norway   1707676983  1282856720  premium        False     False  Champion
# 1  CHENNAI   1707658628  1466301035  premium        False     False   Crystal
#
#          _dlt_load_id         _dlt_id
# 0  1707714360.9280941  0MNDqawMUEKL1Q
# 1  1707714360.9280941  njQM8u2LpPGj7Q

# %% [markdown]
# ### POKEMON EXAMPLE FROM GOOGLE COLAB
#
# https://colab.research.google.com/drive/1NfSB1DpwbbHX9_t5vlalBTf13utwpMGx?usp=sharing#scrollTo=A3NRS0y38alk

# %%
# create pipeline
pipeline = dlt.pipeline(pipeline_name="pokemon_pipeline", destination="duckdb", dataset_name="pokemon_data")

# %%
# get data from the source 

from dlt.sources.helpers import requests

POKEMON_URL = "https://pokeapi.co/api/v2/pokemon/"

data = requests.get(POKEMON_URL).json()["results"]

data
# Out:
# [{'name': 'bulbasaur', 'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#  {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#  {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#  {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#  {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#  {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#  {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#  {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#  {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#  {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#  {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
#  {'name': 'butterfree', 'url': 'https://pokeapi.co/api/v2/pokemon/12/'},
#  {'name': 'weedle', 'url': 'https://pokeapi.co/api/v2/pokemon/13/'},
#  {'name': 'kakuna', 'url': 'https://pokeapi.co/api/v2/pokemon/14/'},
#  {'name': 'beedrill', 'url': 'https://pokeapi.co/api/v2/pokemon/15/'},
#  {'name': 'pidgey', 'url': 'https://pokeapi.co/api/v2/pokemon/16/'},
#  {'name': 'pidgeotto', 'url': 'https://pokeapi.co/api/v2/pokemon/17/'},
#  {'name': 'pidgeot', 'url': 'https://pokeapi.co/api/v2/pokemon/18/'},
#  {'name': 'rattata', 'url': 'https://pokeapi.co/api/v2/pokemon/19/'},
#  {'name': 'raticate', 'url': 'https://pokeapi.co/api/v2/pokemon/20/'}]

# %%
# %%capture
# Normalize and load the data onto the locally created duckdb database 'pokemon_pipeline.duckdb'
pipeline.run(data, table_name='pokemon')

# %%
import duckdb

# a database 'chess_pipeline.duckdb' was created in working directory so just connect to it
conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# this lets us query data without adding schema prefix to table names
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")

# list all tables
display(conn.sql("DESCRIBE"))

stats_table = conn.sql("SELECT * FROM pokemon").df()
display(stats_table)
# Out:
# ┌──────────────────┬──────────────┬─────────────────────┬──────────────────────┬───────────────────────────┬───────────┐
# │     database     │    schema    │        name         │     column_names     │       column_types        │ temporary │
# │     varchar      │   varchar    │       varchar       │      varchar[]       │         varchar[]         │  boolean  │
# ├──────────────────┼──────────────┼─────────────────────┼──────────────────────┼───────────────────────────┼───────────┤
# │ pokemon_pipeline │ pokemon_data │ _dlt_loads          │ [load_id, schema_n…  │ [VARCHAR, VARCHAR, BIGI…  │ false     │
# │ pokemon_pipeline │ pokemon_data │ _dlt_pipeline_state │ [version, engine_v…  │ [BIGINT, BIGINT, VARCHA…  │ false     │
# │ pokemon_pipeline │ pokemon_data │ _dlt_version        │ [version, engine_v…  │ [BIGINT, BIGINT, TIMEST…  │ false     │
# │ pokemon_pipeline │ pokemon_data │ pokemon             │ [name, url, _dlt_l…  │ [VARCHAR, VARCHAR, VARC…  │ false     │
# └──────────────────┴──────────────┴─────────────────────┴──────────────────────┴───────────────────────────┴───────────┘
#           name                                    url        _dlt_load_id  \
# 0    bulbasaur   https://pokeapi.co/api/v2/pokemon/1/  1707715084.0987809
# 1      ivysaur   https://pokeapi.co/api/v2/pokemon/2/  1707715084.0987809
# 2     venusaur   https://pokeapi.co/api/v2/pokemon/3/  1707715084.0987809
# 3   charmander   https://pokeapi.co/api/v2/pokemon/4/  1707715084.0987809
# 4   charmeleon   https://pokeapi.co/api/v2/pokemon/5/  1707715084.0987809
# 5    charizard   https://pokeapi.co/api/v2/pokemon/6/  1707715084.0987809
# 6     squirtle   https://pokeapi.co/api/v2/pokemon/7/  1707715084.0987809
# 7    wartortle   https://pokeapi.co/api/v2/pokemon/8/  1707715084.0987809
# 8    blastoise   https://pokeapi.co/api/v2/pokemon/9/  1707715084.0987809
# 9     caterpie  https://pokeapi.co/api/v2/pokemon/10/  1707715084.0987809
# 10     metapod  https://pokeapi.co/api/v2/pokemon/11/  1707715084.0987809
# 11  butterfree  https://pokeapi.co/api/v2/pokemon/12/  1707715084.0987809
# 12      weedle  https://pokeapi.co/api/v2/pokemon/13/  1707715084.0987809
# 13      kakuna  https://pokeapi.co/api/v2/pokemon/14/  1707715084.0987809
# 14    beedrill  https://pokeapi.co/api/v2/pokemon/15/  1707715084.0987809
# 15      pidgey  https://pokeapi.co/api/v2/pokemon/16/  1707715084.0987809
# 16   pidgeotto  https://pokeapi.co/api/v2/pokemon/17/  1707715084.0987809
# 17     pidgeot  https://pokeapi.co/api/v2/pokemon/18/  1707715084.0987809
# 18     rattata  https://pokeapi.co/api/v2/pokemon/19/  1707715084.0987809
# 19    raticate  https://pokeapi.co/api/v2/pokemon/20/  1707715084.0987809
#
#            _dlt_id
# 0   e/3yQbN3+OJ2Mw
# 1   QHgbZVMEeJLxGw
# 2   WTGoi2Bt6WhgKA
# 3   BG43VLaxmVloQA
# 4   jYcAHFBvYXh/Mg
# 5   aLPRwP6v0g3uQA
# 6   FiA7pxS9+YiYcg
# 7   DVCrmtdMkrspdQ
# 8   WwOiiqvWSbJ56g
# 9   aevF+U7tnl81yg
# 10  EwiY85HF6vZiuA
# 11  H4JHVCV83o0bdA
# 12  STYKNX0SiInnBg
# 13  A/5gaaqw4r43WA
# 14  qf3yIX9d2yWekw
# 15  nl5DevA2m4kfkA
# 16  gL0AqZdfRA8epQ
# 17  4o9i2Z7ywZyIyw
# 18  JfgUPavgA9P07w
# 19  E2sKyDTZw1lP8w

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/60/6c/120ccf0af6d432025b7b3a77bf7f56a470c5e7e1ab4c1674bf8c73ed6c11/streamlit-1.31.0-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.31.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/c5/e4/7fcceef127badbb0d644d730d992410e4f3799b295c9964a172f92a469c7/altair-5.2.0-py3-none-any.whl.metadata
#   Downloading altair-5.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/fa/2a/7f3714cbc6356a0efec525ce7a0613d581072ed6eb53eb7b9754f33db807/blinker-1.7.0-py3-none-any.whl.metadata
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Obtaining dependency information for cachetools<6,>=4.0 from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (10.0.1)
# Collecting protobuf<5,>=3.20 (from streamlit)
#   Obtaining dependency information for protobuf<5,>=3.20 from https://files.pythonhosted.org/packages/c1/00/c3ae19cabb36cfabc94ff0b102aac21b471c9f91a1357f8aafffb9efe8e0/protobuf-4.25.2-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-4.25.2-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Obtaining dependency information for rich<14,>=10.14.0 from https://files.pythonhosted.org/packages/be/be/1520178fa01eabe014b16e72a952b9f900631142ccd03dc36cf93e30c1ce/rich-13.7.0-py3-none-any.whl.metadata
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (4.7.1)
# Collecting tzlocal<6,>=1.1 (from streamlit)
#   Obtaining dependency information for tzlocal<6,>=1.1 from https://files.pythonhosted.org/packages/97/3f/c4c51c55ff8487f2e6d0e618dba917e3c3ee2caae6cf0fbb59c9b1876f2e/tzlocal-5.2-py3-none-any.whl.metadata
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators<1,>=0.2 (from streamlit)
#   Obtaining dependency information for validators<1,>=0.2 from https://files.pythonhosted.org/packages/3a/0c/785d317eea99c3739821718f118c70537639aa43f96bfa1d83a71f68eaf6/validators-0.22.0-py3-none-any.whl.metadata
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (3.1.41)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ---------------------------------------- 0.0/4.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.8 MB ? eta -:--:--
#       --------------------------------------- 0.1/4.8 MB 656.4 kB/s eta 0:00:08
#       --------------------------------------- 0.1/4.8 MB 819.2 kB/s eta 0:00:06
#      - -------------------------------------- 0.2/4.8 MB 833.5 kB/s eta 0:00:06
#      -- ------------------------------------- 0.3/4.8 MB 1.3 MB/s eta 0:00:04
#      --- ------------------------------------ 0.4/4.8 MB 1.4 MB/s eta 0:00:04
#      ---- ----------------------------------- 0.5/4.8 MB 1.8 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.7/4.8 MB 1.8 MB/s eta 0:00:03
#      -------- ------------------------------- 1.0/4.8 MB 2.6 MB/s eta 0:00:02
#      --------- ------------------------------ 1.2/4.8 MB 2.4 MB/s eta 0:00:02
#      ------------ --------------------------- 1.6/4.8 MB 3.0 MB/s eta 0:00:02
#      ---------------- ----------------------- 1.9/4.8 MB 3.4 MB/s eta 0:00:01
#      ------------------- -------------------- 2.3/4.8 MB 3.9 MB/s eta 0:00:01
#      ----------------------- ---------------- 2.8/4.8 MB 4.3 MB/s eta 0:00:01
#      -------------------------- ------------- 3.2/4.8 MB 4.6 MB/s eta 0:00:01
#      ------------------------------ --------- 3.6/4.8 MB 4.9 MB/s eta 0:00:01
#      -------------------------------- ------- 3.9/4.8 MB 5.0 MB/s eta 0:00:01
#      ------------------------------------- -- 4.5/4.8 MB 5.5 MB/s eta 0:00:01
#      ---------------------------------------  4.8/4.8 MB 5.5 MB/s eta 0:00:01
#      ---------------------------------------- 4.8/4.8 MB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\luka\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\luka\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\luka\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\luka\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\luka\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\luka\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\luka\anaconda3\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\luka\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\luka\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\luka\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\luka\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luka\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luka\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luka\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\luka\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\luka\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\luka\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\luka\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\luka\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\luka\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\luka\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Downloading streamlit-1.31.0-py2.py3-none-any.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/8.4 MB 18.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/8.4 MB 12.2 MB/s eta 0:00:01
#    ------ --------------------------------- 1.4/8.4 MB 11.5 MB/s eta 0:00:01
#    --------- ------------------------------ 1.9/8.4 MB 11.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.2/8.4 MB 11.0 MB/s eta 0:00:01
#    ------------- -------------------------- 2.9/8.4 MB 10.9 MB/s eta 0:00:01
#    --------------- ------------------------ 3.3/8.4 MB 10.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.8/8.4 MB 10.5 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.4 MB 10.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.0/8.4 MB 10.9 MB/s eta 0:00:01
#    ------------------------- -------------- 5.3/8.4 MB 10.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.0/8.4 MB 11.0 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.4 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.4 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.7/8.4 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------  8.3/8.4 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 11.2 MB/s eta 0:00:00
# Downloading altair-5.2.0-py3-none-any.whl (996 kB)
#    ---------------------------------------- 0.0/996.9 kB ? eta -:--:--
#    -------------- ------------------------- 358.4/996.9 kB 7.4 MB/s eta 0:00:01
#    --------------------------------------- 996.9/996.9 kB 10.5 MB/s eta 0:00:00
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading protobuf-4.25.2-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --------------------------------------  409.6/413.4 kB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 413.4/413.4 kB 8.8 MB/s eta 0:00:00
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ---------------------------------------- 0.0/240.6 kB ? eta -:--:--
#    ---------------------------------------- 240.6/240.6 kB 7.4 MB/s eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Installing collected packages: validators, tzlocal, protobuf, cachetools, blinker, rich, pydeck, altair, streamlit
# Successfully installed altair-5.2.0 blinker-1.7.0 cachetools-5.3.2 protobuf-4.25.2 pydeck-0.8.1b0 rich-13.7.0 streamlit-1.31.0 tzlocal-5.2 validators-0.22.0

# %% [markdown]
# dlt pipeline quick_start show
#
# this command will run pipeline in streamlit, this command can be run from terminal with actiavate conda env
# https://dlthub.com/docs/getting-started

# %% [markdown]
# ### load data from api tutorial
#
# https://dlthub.com/docs/tutorial/load-data-from-an-api

# %%
import dlt
from dlt.sources.helpers import requests

# Specify the URL of the API endpoint
url = "https://api.github.com/repos/dlt-hub/dlt/issues"
# Make a request and check if it was successful
response = requests.get(url)
response.raise_for_status()

pipeline = dlt.pipeline(
    pipeline_name="github_issues",
    destination="duckdb",
    dataset_name="github_data",
)
# The response contains a list of issues
load_info = pipeline.run(response.json(), table_name="issues")

print(load_info)
# Out:
# Pipeline github_issues load step completed in 0.33 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset github_data
# The duckdb destination used duckdb:///C:\Users\Luka\Desktop\DESK\Studying\DE-zoomcamp\dlt-workshop\github_issues.duckdb location to store data
# Load package 1707723310.8746843 is LOADED and contains no failed jobs

# %% [markdown]
# if we run same script twices it will append data because mode is append

# %%
import duckdb

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
stats_table = conn.sql("SELECT * FROM issues").df()
display(stats_table)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                               repository_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt
# 1   https://api.github.com/repos/dlt-hub/dlt
# 2   https://api.github.com/repos/dlt-hub/dlt
# 3   https://api.github.com/repos/dlt-hub/dlt
# 4   https://api.github.com/repos/dlt-hub/dlt
# 5   https://api.github.com/repos/dlt-hub/dlt
# 6   https://api.github.com/repos/dlt-hub/dlt
# 7   https://api.github.com/repos/dlt-hub/dlt
# 8   https://api.github.com/repos/dlt-hub/dlt
# 9   https://api.github.com/repos/dlt-hub/dlt
# 10  https://api.github.com/repos/dlt-hub/dlt
# 11  https://api.github.com/repos/dlt-hub/dlt
# 12  https://api.github.com/repos/dlt-hub/dlt
# 13  https://api.github.com/repos/dlt-hub/dlt
# 14  https://api.github.com/repos/dlt-hub/dlt
# 15  https://api.github.com/repos/dlt-hub/dlt
# 16  https://api.github.com/repos/dlt-hub/dlt
# 17  https://api.github.com/repos/dlt-hub/dlt
# 18  https://api.github.com/repos/dlt-hub/dlt
# 19  https://api.github.com/repos/dlt-hub/dlt
# 20  https://api.github.com/repos/dlt-hub/dlt
# 21  https://api.github.com/repos/dlt-hub/dlt
# 22  https://api.github.com/repos/dlt-hub/dlt
# 23  https://api.github.com/repos/dlt-hub/dlt
# 24  https://api.github.com/repos/dlt-hub/dlt
# 25  https://api.github.com/repos/dlt-hub/dlt
# 26  https://api.github.com/repos/dlt-hub/dlt
# 27  https://api.github.com/repos/dlt-hub/dlt
# 28  https://api.github.com/repos/dlt-hub/dlt
# 29  https://api.github.com/repos/dlt-hub/dlt
#
#                                            labels_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                                            events_url  \
# 0   https://api.github.com/repos/dlt-hub/dlt/issue...
# 1   https://api.github.com/repos/dlt-hub/dlt/issue...
# 2   https://api.github.com/repos/dlt-hub/dlt/issue...
# 3   https://api.github.com/repos/dlt-hub/dlt/issue...
# 4   https://api.github.com/repos/dlt-hub/dlt/issue...
# 5   https://api.github.com/repos/dlt-hub/dlt/issue...
# 6   https://api.github.com/repos/dlt-hub/dlt/issue...
# 7   https://api.github.com/repos/dlt-hub/dlt/issue...
# 8   https://api.github.com/repos/dlt-hub/dlt/issue...
# 9   https://api.github.com/repos/dlt-hub/dlt/issue...
# 10  https://api.github.com/repos/dlt-hub/dlt/issue...
# 11  https://api.github.com/repos/dlt-hub/dlt/issue...
# 12  https://api.github.com/repos/dlt-hub/dlt/issue...
# 13  https://api.github.com/repos/dlt-hub/dlt/issue...
# 14  https://api.github.com/repos/dlt-hub/dlt/issue...
# 15  https://api.github.com/repos/dlt-hub/dlt/issue...
# 16  https://api.github.com/repos/dlt-hub/dlt/issue...
# 17  https://api.github.com/repos/dlt-hub/dlt/issue...
# 18  https://api.github.com/repos/dlt-hub/dlt/issue...
# 19  https://api.github.com/repos/dlt-hub/dlt/issue...
# 20  https://api.github.com/repos/dlt-hub/dlt/issue...
# 21  https://api.github.com/repos/dlt-hub/dlt/issue...
# 22  https://api.github.com/repos/dlt-hub/dlt/issue...
# 23  https://api.github.com/repos/dlt-hub/dlt/issue...
# 24  https://api.github.com/repos/dlt-hub/dlt/issue...
# 25  https://api.github.com/repos/dlt-hub/dlt/issue...
# 26  https://api.github.com/repos/dlt-hub/dlt/issue...
# 27  https://api.github.com/repos/dlt-hub/dlt/issue...
# 28  https://api.github.com/repos/dlt-hub/dlt/issue...
# 29  https://api.github.com/repos/dlt-hub/dlt/issue...
#
#                                      html_url          id  \
# 0     https://github.com/dlt-hub/dlt/pull/960  2129291323
# 1   https://github.com/dlt-hub/dlt/issues/957  2129181916
# 2     https://github.com/dlt-hub/dlt/pull/956  2128750727
# 3     https://github.com/dlt-hub/dlt/pull/954  2126291188
# 4     https://github.com/dlt-hub/dlt/pull/952  2126134270
# 5     https://github.com/dlt-hub/dlt/pull/950  2125375604
# 6   https://github.com/dlt-hub/dlt/issues/947  2123408014
# 7   https://github.com/dlt-hub/dlt/issues/945  2123039607
# 8   https://github.com/dlt-hub/dlt/issues/944  2123033202
# 9   https://github.com/dlt-hub/dlt/issues/943  2122994665
# 10    https://github.com/dlt-hub/dlt/pull/942  2122973566
# 11  https://github.com/dlt-hub/dlt/issues/934  2120650432
# 12  https://github.com/dlt-hub/dlt/issues/933  2118635297
# 13    https://github.com/dlt-hub/dlt/pull/932  2117900219
# 14  https://github.com/dlt-hub/dlt/issues/931  2114822813
# 15  https://github.com/dlt-hub/dlt/issues/930  2114632757
# 16    https://github.com/dlt-hub/dlt/pull/929  2114031010
# 17  https://github.com/dlt-hub/dlt/issues/928  2113950495
# 18  https://github.com/dlt-hub/dlt/issues/925  2111302906
# 19    https://github.com/dlt-hub/dlt/pull/923  2110164616
# 20  https://github.com/dlt-hub/dlt/issues/919  2108171354
# 21  https://github.com/dlt-hub/dlt/issues/899  2086371089
# 22    https://github.com/dlt-hub/dlt/pull/897  2084357058
# 23    https://github.com/dlt-hub/dlt/pull/896  2083657427
# 24    https://github.com/dlt-hub/dlt/pull/891  2079216487
# 25  https://github.com/dlt-hub/dlt/issues/880  2070297949
# 26  https://github.com/dlt-hub/dlt/issues/875  2065770966
# 27  https://github.com/dlt-hub/dlt/issues/873  2062695442
# 28  https://github.com/dlt-hub/dlt/issues/860  2057766820
# 29  https://github.com/dlt-hub/dlt/issues/858  2056675584
#
#                 node_id  number  \
# 0   PR_kwDOGvRYu85mlzbr     960
# 1    I_kwDOGvRYu85-6Lzc     957
# 2   PR_kwDOGvRYu85mkOTB     956
# 3   PR_kwDOGvRYu85mb7da     954
# 4   PR_kwDOGvRYu85mbZvc     952
# 5   PR_kwDOGvRYu85mYxul     950
# 6    I_kwDOGvRYu85-kKKO     947
# 7    I_kwDOGvRYu85-iwN3     945
# 8    I_kwDOGvRYu85-iupy     944
# 9    I_kwDOGvRYu85-ilPp     943
# 10  PR_kwDOGvRYu85mQlpK     942
# 11   I_kwDOGvRYu85-Zo7A     934
# 12   I_kwDOGvRYu85-R88h     933
# 13  PR_kwDOGvRYu85l_RRO     932
# 14   I_kwDOGvRYu85-DaKd     931
# 15   I_kwDOGvRYu85-Crw1     930
# 16  PR_kwDOGvRYu85lyIQe     929
# 17   I_kwDOGvRYu85-AFMf     928
# 18   I_kwDOGvRYu8591-z6     925
# 19  PR_kwDOGvRYu85lkwr2     923
# 20   I_kwDOGvRYu859qCRa     919
# 21   I_kwDOGvRYu858W38R     899
# 22  PR_kwDOGvRYu85kNykk     897
# 23  PR_kwDOGvRYu85kLWdO     896
# 24  PR_kwDOGvRYu85j8fed     891
# 25   I_kwDOGvRYu857Zj1d     880
# 26   I_kwDOGvRYu857ISnW     875
# 27   I_kwDOGvRYu8568jwS     873
# 28   I_kwDOGvRYu856pwek     860
# 29   I_kwDOGvRYu856lmEA     858
#
#                                                 title  ...  \
# 0             Introduce `replicate` write disposition  ...
# 1   publish a stable dependence freeze for core li...  ...
# 2   Clarify info about GoodData in modelling tools...  ...
# 3                    Add git to filesystem source 301  ...
# 4       855 create bigquery adapter for dlt resources  ...
# 5   Tweaked output to not include "Found schema" a...  ...
# 6     Core extensions to support database replication  ...
# 7   allow to define maximum nesting level per reso...  ...
# 8   Allow to backup and restore pipeline working d...  ...
# 9            use pydata_google_auth in GcpCredentials  ...
# 10                             annotations experiment  ...
# 11   Simplify Parallelization for generator resources  ...
# 12                      Postgres database replication  ...
# 13    feat(filesystem): implement Google Drive source  ...
# 14  Airflow helper: expose internal runner and int...  ...
# 15  Extended filesystem layout placeholders for de...  ...
# 16  Added info about "Rows count" and "Data loadin...  ...
# 17  Warning persists when using `dlt` in local or ...  ...
# 18    Save compressed load files with `.gz` extension  ...
# 19                                    SCD2 Experiment  ...
# 20  Ability to define /configure target schema for...  ...
# 21      Pluggable File Formats including AVRO support  ...
# 22                          Format and lint with Ruff  ...
# 23                             Add some missing tests  ...
# 24                              data sink destination  ...
# 25  Normalize keys for google secrets lookup (or d...  ...
# 26              Finish cleanup of repository env vars  ...
# 27                        Schema management only mode  ...
# 28  `drop_storage()` leaves empty folders dangling...  ...
# 29  [chores] use `dataclass_transform` to autogene...  ...
#
#                               assignee__following_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   https://api.github.com/users/Pipboyguy/followi...
# 5                                                None
# 6   https://api.github.com/users/jorritsandbrink/f...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  https://api.github.com/users/steinitzu/followi...
# 12  https://api.github.com/users/jorritsandbrink/f...
# 13                                               None
# 14  https://api.github.com/users/IlyaFaer/followin...
# 15  https://api.github.com/users/sultaniman/follow...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  https://api.github.com/users/sultaniman/follow...
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/sultaniman/follow...
# 26  https://api.github.com/users/sh-rp/following{/...
# 27                                               None
# 28                                               None
# 29                                               None
#
#                                   assignee__gists_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   https://api.github.com/users/Pipboyguy/gists{/...
# 5                                                None
# 6   https://api.github.com/users/jorritsandbrink/g...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  https://api.github.com/users/steinitzu/gists{/...
# 12  https://api.github.com/users/jorritsandbrink/g...
# 13                                               None
# 14  https://api.github.com/users/IlyaFaer/gists{/g...
# 15  https://api.github.com/users/sultaniman/gists{...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  https://api.github.com/users/sultaniman/gists{...
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/sultaniman/gists{...
# 26  https://api.github.com/users/sh-rp/gists{/gist...
# 27                                               None
# 28                                               None
# 29                                               None
#
#                                 assignee__starred_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   https://api.github.com/users/Pipboyguy/starred...
# 5                                                None
# 6   https://api.github.com/users/jorritsandbrink/s...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  https://api.github.com/users/steinitzu/starred...
# 12  https://api.github.com/users/jorritsandbrink/s...
# 13                                               None
# 14  https://api.github.com/users/IlyaFaer/starred{...
# 15  https://api.github.com/users/sultaniman/starre...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  https://api.github.com/users/sultaniman/starre...
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/sultaniman/starre...
# 26  https://api.github.com/users/sh-rp/starred{/ow...
# 27                                               None
# 28                                               None
# 29                                               None
#
#                           assignee__subscriptions_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   https://api.github.com/users/Pipboyguy/subscri...
# 5                                                None
# 6   https://api.github.com/users/jorritsandbrink/s...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  https://api.github.com/users/steinitzu/subscri...
# 12  https://api.github.com/users/jorritsandbrink/s...
# 13                                               None
# 14  https://api.github.com/users/IlyaFaer/subscrip...
# 15  https://api.github.com/users/sultaniman/subscr...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  https://api.github.com/users/sultaniman/subscr...
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/sultaniman/subscr...
# 26   https://api.github.com/users/sh-rp/subscriptions
# 27                                               None
# 28                                               None
# 29                                               None
#
#                           assignee__organizations_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4         https://api.github.com/users/Pipboyguy/orgs
# 5                                                None
# 6   https://api.github.com/users/jorritsandbrink/orgs
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11        https://api.github.com/users/steinitzu/orgs
# 12  https://api.github.com/users/jorritsandbrink/orgs
# 13                                               None
# 14         https://api.github.com/users/IlyaFaer/orgs
# 15       https://api.github.com/users/sultaniman/orgs
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22       https://api.github.com/users/sultaniman/orgs
# 23                                               None
# 24                                               None
# 25       https://api.github.com/users/sultaniman/orgs
# 26            https://api.github.com/users/sh-rp/orgs
# 27                                               None
# 28                                               None
# 29                                               None
#
#                                   assignee__repos_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4        https://api.github.com/users/Pipboyguy/repos
# 5                                                None
# 6   https://api.github.com/users/jorritsandbrink/r...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11       https://api.github.com/users/steinitzu/repos
# 12  https://api.github.com/users/jorritsandbrink/r...
# 13                                               None
# 14        https://api.github.com/users/IlyaFaer/repos
# 15      https://api.github.com/users/sultaniman/repos
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22      https://api.github.com/users/sultaniman/repos
# 23                                               None
# 24                                               None
# 25      https://api.github.com/users/sultaniman/repos
# 26           https://api.github.com/users/sh-rp/repos
# 27                                               None
# 28                                               None
# 29                                               None
#
#                                  assignee__events_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4   https://api.github.com/users/Pipboyguy/events{...
# 5                                                None
# 6   https://api.github.com/users/jorritsandbrink/e...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  https://api.github.com/users/steinitzu/events{...
# 12  https://api.github.com/users/jorritsandbrink/e...
# 13                                               None
# 14  https://api.github.com/users/IlyaFaer/events{/...
# 15  https://api.github.com/users/sultaniman/events...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22  https://api.github.com/users/sultaniman/events...
# 23                                               None
# 24                                               None
# 25  https://api.github.com/users/sultaniman/events...
# 26  https://api.github.com/users/sh-rp/events{/pri...
# 27                                               None
# 28                                               None
# 29                                               None
#
#                         assignee__received_events_url assignee__type  \
# 0                                                None           None
# 1                                                None           None
# 2                                                None           None
# 3                                                None           None
# 4   https://api.github.com/users/Pipboyguy/receive...           User
# 5                                                None           None
# 6   https://api.github.com/users/jorritsandbrink/r...           User
# 7                                                None           None
# 8                                                None           None
# 9                                                None           None
# 10                                               None           None
# 11  https://api.github.com/users/steinitzu/receive...           User
# 12  https://api.github.com/users/jorritsandbrink/r...           User
# 13                                               None           None
# 14  https://api.github.com/users/IlyaFaer/received...           User
# 15  https://api.github.com/users/sultaniman/receiv...           User
# 16                                               None           None
# 17                                               None           None
# 18                                               None           None
# 19                                               None           None
# 20                                               None           None
# 21                                               None           None
# 22  https://api.github.com/users/sultaniman/receiv...           User
# 23                                               None           None
# 24                                               None           None
# 25  https://api.github.com/users/sultaniman/receiv...           User
# 26  https://api.github.com/users/sh-rp/received_ev...           User
# 27                                               None           None
# 28                                               None           None
# 29                                               None           None
#
#    assignee__site_admin
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                 False
# 5                   NaN
# 6                 False
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                False
# 12                False
# 13                  NaN
# 14                False
# 15                False
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                False
# 23                  NaN
# 24                  NaN
# 25                False
# 26                False
# 27                  NaN
# 28                  NaN
# 29                  NaN
#
# [30 rows x 71 columns]

# %% [markdown]
# to solve that problem, we can use another mode / replace mode

# %%
import dlt
from dlt.sources.helpers import requests

# Specify the URL of the API endpoint
url = "https://api.github.com/repos/dlt-hub/dlt/issues"
# Make a request and check if it was successful
response = requests.get(url)
response.raise_for_status()

pipeline = dlt.pipeline(
    pipeline_name='github_issues',
    destination='duckdb',
    dataset_name='github_data',
)
# The response contains a list of issues
load_info = pipeline.run(
    response.json(),
    table_name="issues",
    write_disposition="replace"  # <-- Add this line
)

print(load_info)
# Out:
# Pipeline github_issues load step completed in 0.32 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset github_data
# The duckdb destination used duckdb:///C:\Users\Luka\Desktop\DESK\Studying\DE-zoomcamp\dlt-workshop\github_issues.duckdb location to store data
# Load package 1707723503.0704467 is LOADED and contains no failed jobs
